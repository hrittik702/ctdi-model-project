# %% [markdown]
# ## Generating Missing fig

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/raw/air_quality/epd_air_quality_2019_2021_hourly.csv')
CRITERIA = ['pm25', 'pm10', 'no2', 'so2', 'o3']
df['missing'] = df[CRITERIA].isna().sum(axis=1) 
total_missing = df['missing'].sum()

# %%
st = df.groupby('station_name')['missing'].sum()
st
# Out:
# station_name
# CAUSEWAY BAY       3672
# CENTRAL            2936
# CENTRAL/WESTERN    2388
# EASTERN            3612
# KWAI CHUNG         3161
# KWUN TONG          4203
# MONG KOK           2760
# SHAM SHUI PO       4206
# SHATIN             4759
# TAI PO             2489
# TAP MUN            4578
# TSEUNG KWAN O      2410
# TSUEN WAN          3980
# TUEN MUN           2565
# TUNG CHUNG         4018
# YUEN LONG          4139
# Name: missing, dtype: int64
